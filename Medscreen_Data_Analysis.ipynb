# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.api.types import is_numeric_dtype
from pylab import rcParams
import seaborn as sb
sb.set_style('darkgrid')
rcParams['figure.figsize'] = 8,8
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
data = pd.read_csv("/home/prince/Salomey_Addo/REPORT DATA.csv")

# %%
# let us take a look at the data set
data.head(100)
# Out:
#     LAB NO GENDER  AGE  PULSE  BP SYSTOLIC  BP DIASTOLIC  TEMPERATURE  WEIGHT  \
# 0     64.0      M    2   95.0          NaN           NaN         36.3     NaN
# 1      NaN      M   37    NaN          NaN           NaN          NaN     NaN
# 2     38.0      F   14   84.0          NaN           NaN         36.4    38.7
# 3      NaN      M   24    NaN        118.0          70.0          NaN     NaN
# 4      9.0      M   31   97.0        118.0          87.0         35.9    58.7
# 5     82.0      F    8   95.0          NaN           NaN         36.6    19.0
# 6     65.0      F    7   92.0          NaN           NaN         36.7    20.0
# 7     66.0      F   10   90.0          NaN           NaN         36.7    26.0
# 8     53.0      F    1  114.0          NaN           NaN         36.4     NaN
# 9     49.0      F    3   82.0          NaN           NaN         36.5     NaN
# 10    50.0      M    1   67.0          NaN           NaN         36.6     NaN
# ...

# %%
#check the shape of the data sets
print ('the data set has '+str(data.shape[0]) +' rows and  '+ str(data.shape[1]) + ' columns')
# Out:
# the data set has 110 rows and  19 columns

# %%
# let us check the numerical and categorical variables we have
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 19 columns):
# LAB NO              97 non-null float64
# GENDER              110 non-null object
# AGE                 110 non-null int64
# PULSE               98 non-null float64
# BP SYSTOLIC         50 non-null float64
# BP DIASTOLIC        50 non-null float64
# TEMPERATURE         101 non-null float64
# WEIGHT              99 non-null float64
# BMI                 80 non-null float64
# HEPATITIS B TEST    108 non-null object
# GLUCOSE TEST        26 non-null float64
# REFERRED OR NOT     14 non-null object
# MOAC                8 non-null float64
# HT                  69 non-null float64
# BF                  40 non-null float64
# MF                  40 non-null float64
# VF                  39 non-null float64
# RM                  40 non-null float64
# MALARIA             1 non-null object
# dtypes: float64(14), int64(1), object(4)
# memory usage: 16.4+ KB

# %% [markdown]
# Univariate Analysis

# %%
# let us plot a bar graph of the number of males and females we examined
print(data["GENDER"].value_counts(normalize = False).plot(kind="bar", stacked = False, figsize=(15,7)))
#plt.figure(figsize=(10,5))
plt.ylabel("counts")
plt.xlabel("Gender")
import matplotlib.pyplot
plt.title('The number of male and female screened')
print(data["GENDER"].value_counts(normalize = False))
#plt.show()
# Out:
# Axes(0.125,0.125;0.775x0.755)
# M    59
# F    51
# Name: GENDER, dtype: int64

# %%
# let us plot a bar graph of the number of people who tested positive or negative for Hepatitis B
print(data["HEPATITIS B TEST"].value_counts(normalize = False).plot(kind="bar", stacked = False, figsize=(15,7)))
#plt.figure(figsize=(10,5))
plt.ylabel("counts")
plt.xlabel("Hepatitis B test")
plt.title('The number of people with or without Hepatitis B')
print(data["HEPATITIS B TEST"].value_counts())
# Out:
# Axes(0.125,0.125;0.775x0.755)
# NEG    98
# POS    10
# Name: HEPATITIS B TEST, dtype: int64

# %%
# let us plot a bar graph of the number of people who were referred to the hospital
print(data["REFERRED OR NOT"].value_counts(normalize = False).plot(kind="bar", stacked = False, figsize=(15,7)))
#plt.figure(figsize=(10,5))
plt.ylabel("counts")
#plt.xlabel("REFERRE")
plt.title("The number of people reffered to the main hospital")
# Out:
# Axes(0.125,0.125;0.775x0.755)

# %%
#Check summary of categorical data
data.select_dtypes(include=["object"]).describe().T
# Out:
#                  count unique            top freq
# GENDER             110      2              M   59
# HEPATITIS B TEST   108      2            NEG   98
# REFERRED OR NOT     14      6  YES FOR HEP B    9
# MALARIA              1      1         NO MPS    1

# %%
# check a summary of our numerical features
data.select_dtypes(include =["float64"]).describe().T
# Out:
#               count        mean        std    min      25%     50%      75%  \
# LAB NO         97.0   49.608247  28.026608    1.0   26.000   50.00   74.000
# PULSE          98.0   89.551020  20.476349   54.0   79.000   88.50   96.500
# BP SYSTOLIC    50.0  119.940000  22.746527   90.0  108.250  118.00  130.000
# BP DIASTOLIC   50.0   74.340000  14.437211   53.0   65.000   70.00   80.000
# TEMPERATURE   101.0   36.519802   0.354689   35.4   36.400   36.60   36.700
# WEIGHT         99.0   42.789899  24.188741    8.0   19.500   40.70   61.600
# BMI            80.0   21.177500   7.410598   10.9   14.900   20.45   25.025
# GLUCOSE TEST   26.0    5.811538   1.065205    4.3    5.100    5.60    6.475
# MOAC            8.0   14.800000   1.706291   13.2   13.850   14.25   15.075
# HT             69.0  150.746377  16.540864  100.0  143.000  155.00  163.000
# BF             40.0   28.075000  13.483832    7.8   17.950   24.50   38.400
# ...

# %%
# check a summary of the ages 
data.select_dtypes(include =["int64"]).describe().T
# Out:
#      count       mean        std  min  25%   50%    75%   max
# AGE  110.0  19.854545  16.254759  1.0  8.0  14.0  28.75  80.0

# %%
# encoding the categorical variable
data["HEPATITIS B TEST"] = data["HEPATITIS B TEST"].astype("category").cat.codes

# %% [markdown]
# Multivariate Analysis

# %%
# finding the relationship between age and BP systolic
import matplotlib.pyplot
plt.figure(figsize=(15,7))
x = sns.regplot(data["BP SYSTOLIC"],data["AGE"])
#matplotlib.pyplot.scatter(data["BP SYSTOLIC"],data["AGE"])
plt.title("Scatter plot of Age and BP Systolic")
plt.show()

# %%
# finding the relationship between age and BP diastolic
import matplotlib.pyplot
plt.figure(figsize=(15,7))
y=sns.regplot(data["BP DIASTOLIC"],data["AGE"])
#matplotlib.pyplot.scatter(data["BP DIASTOLIC"],data["AGE"])
plt.title("Scatter plot of Age and BP Systolic")
plt.show()

# %%
# plotting a box plot for Hepatitis B test and Age
import seaborn as sns
plt.figure(figsize=(20,10))
ax = sns.boxplot(x=data["HEPATITIS B TEST"] , y=data["AGE"])
plt.title("Box plot of Hepatitis B test and BP Age")
plt.show()

# %%
#finding the correlation among the variables
data.corr()
# Out:
#                     LAB NO       AGE     PULSE  BP SYSTOLIC  BP DIASTOLIC  \
# LAB NO            1.000000 -0.283969  0.032588     0.049221      0.018567
# AGE              -0.283969  1.000000 -0.284132     0.512472      0.394555
# PULSE             0.032588 -0.284132  1.000000     0.012632     -0.007258
# BP SYSTOLIC       0.049221  0.512472  0.012632     1.000000      0.804964
# BP DIASTOLIC      0.018567  0.394555 -0.007258     0.804964      1.000000
# TEMPERATURE       0.162780 -0.379675  0.137085    -0.200239     -0.297939
# WEIGHT           -0.360808  0.766921 -0.320191     0.380891      0.379542
# BMI              -0.354753  0.638120 -0.273269     0.320140      0.375405
# HEPATITIS B TEST -0.146284  0.221754  0.034728    -0.025313      0.215504
# GLUCOSE TEST      0.104927  0.296026 -0.136895     0.120372      0.188626
# MOAC              0.819994  0.142762 -0.328238          NaN           NaN
# HT               -0.399101  0.519261 -0.039634    -0.110813     -0.083788
# ...
